# %% [markdown]
# # Double inflation
# ## Background Dynamics
# We consider a model consisting of two scalar fields, say, $\phi$ and $\chi$, whose dynamics is governed by the following action:
# $$
# S=\int d^4x\sqrt{-g}\left[\frac{M_\text{P}^2}{2}R-\frac{1}{2}(\partial\phi)^2-\frac{f(\phi)}{2}(\partial\chi)^2-V(\phi,\chi)\right]\,,
# $$
# where $\phi$ is a cononical scalar field, $\chi$ is a non-canonical scalar field due to the presence of the function $f(\phi)$ in the term describing its kinetic energy. $M_\text{P}$ is reduced  Plank mass. We consider the following double inflation model:
# $$
# V(\phi,\chi)=\frac{1}{2}m_\phi^2\phi^2+\frac{1}{2}m_\chi^2 \chi^2\,.
# $$
# In order to connect with the equation of other works, we define $f(\phi)=e^{2b(\phi)}$.
# We work with the spactially flat Friedmann-Robertson-Walker (FRW) universe by the line-element
# $$
# ds^2=-dt^2+a^2(t)dx^2\,,
# $$
# where $a(t)$ is the scale factor and $t$ is the cosmic time. In this background, the equations of motion (EOM) is given by (Euler-Lagrange equation):
#
# $$\ddot\phi+3H\dot\phi+V_{,\phi}=b_\phi e^{2b}\dot\chi^2\,,$$
#
# $$\ddot\chi+\left(3H+2b_\phi\dot\phi\right)\dot\chi+e^{-2b}V_{,\chi}=0\,.$$
#
# The dynamics of the scale factor is described by the following Friedmann equations:
#
# $$H^2=\frac{1}{3M_\text{P}^2}\left[\frac{\dot\phi^2}{2}+e^{2b}\frac{\dot\chi^2}{2}+V\right]\,,$$
# $$\dot H=-\frac{1}{2M_\text{P}^2}\left[\dot\phi^2+e^{2b}\dot\chi^2\right]\,.$$
#
#  At this point, we can solve equations and obtain trajectory. We put the code for differentiating the cosmic time at the end.

# %% [markdown]
# ## Use N (e-folds) to express the equations
#
# By taking the derivative of the above equation with respect to the number of e-folds $N=\ln a$, we obtain
#
# $$\dot\phi=\frac{d}{dt}\phi=\frac{d}{dN}\frac{dN}{dt}\phi=H\phi'\,,$$
#
# $$\ddot\phi=\frac{d}{dt}(H\phi')=HH'\phi'+H^2\phi''\,.$$
#
# where, as usual, the primes represent differentiation with respect to the e-folds. Then the equation of motion becomes:
#
# $$\phi''=-(3+\frac{H'}{H})\phi'-\frac{V_\phi}{H^2}+b_\phi e^{2b}\chi^{\prime 2}=-[3-\frac{1}{2}(\phi'^2+e^{2b}\chi'^2)]\phi'-\frac{V_\phi}{H^2}+b_\phi e^{2b}\chi^{\prime 2}\,,$$
#
# $\chi$ is also completely similar:
# $$\chi''=-(3+\frac{H'}{H}+2b_\phi\phi')\chi'-e^{-2b}\frac{V_\chi}{H^2}=-[3-\frac{1}{2}(\phi'^2+e^{2b}\chi'^2)+2b_\phi\phi']\chi'-e^{-2b}\frac{V_\chi}{H^2}\,.$$
#
# Friedmann equations and scale factor become
# $$H^2=\frac{2V}{6M_p^2+\phi'^2+e^{2b}\chi'^2}$$
#
# $$H'=\frac{\dot H}{H}=-\frac{1}{2}H(\phi'^2+e^{2b}\chi'^2)\,,$$
#
# $$a'=\frac{d a}{d lna}=a\,.$$
#
#
# We also define the dimensionless parameters
# $$N=N \qquad x_1=\frac{\phi}{M_\text{P}}\qquad x_2=\frac{\chi}{M_\text{P}}$$
# $$y_1=\frac{\phi^\prime}{M_\text{P}}\qquad y_2=\frac{\chi\prime}{M_\text{P}}\qquad  z=\frac{H}{M_\text{P}}\qquad a=a\,.$$
# EOM, sacle factor and  Friedmann Equations become
# $$\frac{dx_1}{dN}=y_1\qquad \frac{dx_2}{dN}=y_2\,,$$
# $$\frac{dy_1}{dN}=-\left[3-\frac{1}{2}(y_1^2+e^{2b}y_2^2) \right]\cdot y_1 - \frac{\hat V_\phi}{z^2 }+b_\phi e^{2b}x_2^2\,,$$
# $$\frac{dy_2}{dN}=-\left[3-\frac{1}{2}(y_1^2+e^{2b}y_2^2)+2b_\phi y_1\right]\cdot y_2 - e^{-2b}\frac{\hat V_\chi}{z^2}\,,$$
# $$\frac{dz}{dN}=-\frac{1}{2}\cdot z\cdot(y_1^2+e^{2b}y_2^2)\,,$$
# $$\frac{da}{dN}=a\,.$$
# In different models, parameters' form is different. In the double inflation we use the following parameters:
# $$b=0\qquad b_\phi=0\qquad e^{2b}=1\qquad e^{-2b}=1\qquad \hat V=\frac{V}{M^4_{\rm P}}=\frac{1}{2M^4_{\rm P}}m_\phi^2\phi^2+\frac{1}{2M^4_{\rm P}}m_\chi^2 \chi^2\qquad \hat V_\phi=\frac{V_\phi}{M_{\rm P}^3}=\frac{m^2_\phi x_1}{M_{\rm P}^2}\qquad \hat V_\chi=\frac{V_\chi}{M_{\rm P}^3}=\frac{m^2_\chi x_2}{M_{\rm P}^2}$$
# # Initial condition of SR approximation
# We select initial values:
# $$M_{\rm P}=1\qquad\qquad m_\phi=10^{-6}M_{\rm P}\qquad m_\chi=15m_\phi\qquad x_{1i}=10\qquad x_{2i}=10\qquad a_{i}=1$$
# considering Slow roll approximation, we have
# $$|\ddot \phi|\ll |3H\dot\phi|\,,|V_\phi|$$
# $$|\ddot \chi|\ll |3H\dot\chi|\,,|V_\chi|$$
# The EOM can be written as:
# $$\ddot\phi+3H\dot\phi+V_{,\phi}=b_\phi e^{2b}\dot\chi^2\qquad \dot\phi=\frac{b_\phi e^{2b}\dot\chi^2-V_{,\phi}}{3H}\qquad y_{1i}=\frac{b_\phi e^{2b}y_{2i}^2-\hat V_{,\phi}}{3z_i}\,,$$
#
# $$\ddot\chi+\left(3H+2b_\phi\dot\phi\right)\dot\chi+e^{-2b}V_{,\chi}=0\qquad \dot\chi=-\frac{e^{-2b}V_{,\chi}}{\left(3H+2b_\phi\dot\phi\right)}\qquad y_{2i}=-\frac{e^{-2b}\hat V_{,\chi}}{\left(3z_i+2b_\phi y_{1i}\right)}\,.$$
# Friedman equation and the initial value of $z$:
# $$H^2=\frac{1}{3M_\text{P}^2}\left[\frac{\dot\phi^2}{2}+e^{2b}\frac{\dot\chi^2}{2}+V\right]\qquad z_i=\sqrt{\frac{1}{3}\left[\frac{y_{2i}^2}{2}+e^{2b}\frac{y_{2i}^2}{2}+\hat V\right]}\,,$$
# The initial value can be summarized as：
# $$M_\rm P=1\qquad m_\phi=10^{-6} M_\rm P \qquad m_\chi=15m_\phi  \qquad x_{1i}=10\qquad x_{2i}=10\qquad a_i=1$$
# $$
# \begin{cases} y_{1i}=\frac{b_\phi e^{2b}y_{2i}^2-\hat V_{,\phi}}{3z_i} \\
# y_{2i}=-\frac{e^{-2b}\hat V_{,\chi}}{\left(3z_i+2b_\phi y_{1i}\right)}\\
# z_i=\sqrt{\frac{1}{3}\left[\frac{y_{2i}^2}{2}+e^{2b}\frac{y_{2i}^2}{2}+\hat V\right]}\\
# \end{cases}
# $$
# Note that here $y_i$ is the derivative of the universe time. If it is the derivative of N, we need $y_i=\frac{y_i}{z_i}$. Considering the real part, we have:

# %%
import numpy as np
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt
from sympy import symbols, Eq, solve, re
m_p=1#plank mass
mphi=1e-6*m_p
mchi=15*mphi
def e2b(x1):
    return 1
def em2b(x1):
    return 1/e2b(x1)
def b_phi(x1):
    return 0
def V_phi(x1):
    return mphi**2*x1/m_p**2
def V_chi(x2):
    return mchi**2*x2/m_p**2
def Vp(x1,x2):
    return (mchi**2*x2**2+mphi**2*x1**2)/(2*m_p**4)
y1,y2, z = symbols('y1 y2 z')
x1 = 10
x2=10
a=1
eq1 = Eq(y1, (-V_phi(x1)+b_phi(x1)*e2b(x1)*y2**2) / (3 * z))#yi equation
eq2= Eq(y2, -(em2b(x1)*V_chi(x2)) / (3 * z+2*b_phi(x1)*y1))
eq3 = Eq(z, ((y1**2/2 + e2b(x1)*y2**2/2+Vp(x1,x2)) / 3)**0.5)#zi equation
solutions = solve((eq1, eq2,eq3), (y1, y2, z))
print(solutions)
x1i=x1
x2i=x2
ai=a
y1i = re(solutions[0][0])
y2i = re(solutions[0][1])
zi = re(solutions[0][2])
y1i=y1i/zi
y2i=y2i/zi
zi=zi
print(f'The initial value of x1: {x1i}\nThe initial value of x2: {x2i}\nThe initial value of y1: {y1i}\nThe initial value of y2: {y2i}\nThe initial value of z: {zi}\n The initial value of a: {ai}')
# Out:
# [(-5.41351412412977e-8, -1.21804067792920e-5, 6.15742982635917e-5), (6.70329432898373e-7*I, 0.000150824122402134*I, 4.97267935695536e-6*I)]
# The initial value of x1: 10
# The initial value of x2: 10
# The initial value of y1: -0.000879184055164576
# The initial value of y2: -0.197816412412030
# The initial value of z: 0.0000615742982635917
#  The initial value of a: 1

# %%
def sys(t, var):
    x1,x2, y1,y2, z, a = var
    dx1dN = y1
    dx2dN=y2
    dy1dN = -(3 - 0.5 * (y1**2+e2b(x1)*y2**2)) * y1 - V_phi(x1) / (z**2)+b_phi(x1)*e2b(x1)*x2**2
    dy2dN = -(3 - 0.5 * (y1**2+e2b(x1)*y2**2)+2*b_phi(x1)*y1) * y2 - em2b(x1)*V_chi(x2) / (z**2)
    dzdN = -0.5 * z * (y1**2+e2b(x1)*y2**2)
    dadN = a
    return [dx1dN,dx2dN, dy1dN,dy2dN, dzdN, dadN]

N = np.linspace(0, 65, 10000)  # Time points where solution is needed

# invoking the ODE solver
sol = solve_ivp(sys, [N[0], N[-1]], [x1i,x2i, y1i,y2i, zi, ai], t_eval=N, rtol=1e-8, atol=1e-10, method='RK45')
t = sol.t
x1,x2, y1,y2, z, a = sol.y
phi,chi,phi_N,chi_N, H = x1*m_p,x2*m_p, y1*m_p**2,y2*m_p**2, z*m_p

plt.plot(phi, chi, 'r')
plt.xlabel(r'$\phi$')
plt.ylabel(r'$\chi $')
plt.show()

plt.plot(N, phi, label=r'$\phi$')
plt.plot(N, phi_N, label=r'$\phi\prime$')
plt.plot(N, chi, label=r'$\chi$')
plt.plot(N, chi_N, label=r'$\chi\prime$')
plt.legend()
plt.xlabel('N')
plt.show()

plt.plot(phi, phi_N, label=r'$\phi&\phi\prime$')
plt.plot(chi, chi_N, label=r'$\chi&\chi\prime$')
plt.legend()
plt.show()

# %% [markdown]
# ## Slow roll parameters
#
# $$\epsilon_H=-\frac{\dot H}{H^2}=\frac{1}{2}(\phi\prime^2+\chi\prime^2)=1-\frac{a\ddot a }{\dot a^2}$$
#
# During the inflationary period, the potential energy dominates, and $\epsilon_H$ is approximately zero. Inflation ends when $a = 0$, at which point $\epsilon = 1$."
#
# $$\eta_H=\frac{\ddot \phi}{H\dot\phi}=\epsilon_H+\frac{1}{2\epsilon_H}\frac{d\epsilon_H}{dN}$$
# However, in this note we use the defination:
# $$\eta_H=\frac{\dot\epsilon_H}{H\epsilon_H}=\frac{\epsilon_H'}{\epsilon_H}=\frac{\phi'\phi''+\chi'\chi''}{\epsilon_H}$$
#
# It starts small and then oscillates with the subsequent oscillation of $\epsilon$.

# %%
eps=0.5*(phi_N**2+chi_N**2)
plt.plot(N, eps, label=r'$\epsilon_H$')
plt.axhline(1, color='black')
plt.legend()
plt.xlabel('N')
plt.show()
index_of_inflation_end = np.argmin(np.abs(eps - 1)) 
End_inflation=N[index_of_inflation_end]
print(f'The end of inflation: N= {End_inflation}')


phi_NN=-(3 - 0.5 * (y1**2+e2b(x1)*y2**2)) * y1 - V_phi(x1) / (z**2)+b_phi(x1)*e2b(x1)*x2**2
chi_NN=-(3 - 0.5 * (y1**2+e2b(x1)*y2**2)+2*b_phi(x1)*y1) * y2 - em2b(x1)*V_chi(x2) / (z**2)
eta=(phi_N*phi_NN+chi_N*chi_NN)/eps
plt.plot(N, eta, label=r'$\eta_H $')
plt.legend()
plt.xlabel('N')
plt.xlim(1,End_inflation)
plt.ylim(-4,4)
plt.show()
# Out:
# The end of inflation: N= 52.57075707570757

# %% [markdown]
# ## Equations and code respect to the cosmic time
#
# In order to allow e-folds and scale factor to appear naturally, we need to redefine these dimensionless variables, which will facilitate our subsequent processing of the power spectrum.
#
# $$T=t\cdot m_p\qquad x_1=\frac{\phi}{m_p}\qquad x_2=\frac{\chi}{m_p}$$
#
# $$y_1=\frac{\dot\phi}{m_p^2}\qquad y_2=\frac{\dot\chi}{m_p^2}\qquad z=\frac{H}{m_p}\qquad a=a$$
#
# EOM and sacle factor Friedmann Equations become:
#
# $$\frac{dx_1}{dT}=y_1\qquad \frac{dx_2}{dT}=y_2$$
#
# $$\frac{dy_1}{dT}=-3zy_1-\frac{V_\phi}{M_\text{P}^3}$$
#
# $$\frac{dy_2}{dT}=-3zy_2-\frac{V_\chi}{M_\text{P}^3}$$
#
# $$\frac{dz}{dT}=-\frac{1}{2}(y_1^2+y_2^2)\qquad \frac{da}{dT}=az$$
#
# Slow roll parameters are:
#
# $$\epsilon_H=-\frac{\dot H}{H^2}=1-\frac{a\ddot a }{\dot a^2}$$
#
# $$\eta_H=\frac{\ddot \phi}{H\dot\phi}=\epsilon_H+\frac{1}{2\epsilon_H}\frac{d\epsilon_H}{dN}$$
# note, it is better to use another defintion of $\eta_H$

# %%
# import numpy as np
# from scipy.integrate import odeint
# import matplotlib.pyplot as plt

# ### initial conditions for the given system
# m_p=1#plank mass
# mphi=1e-7*m_p
# mchi=15*mphi

# x1i = 10 # initial value of phi
# x2i=10#chi
# y1i = 0# phi velocit(phi_dot)
# y2i=0#chi_dot
# zi = np.sqrt((y1i**2+y2i**2)/(6*m_p**6) + (mphi**2*x1i**2+mchi**2*x2i**2)/(6*m_p**4)) # initial value of hubble constant , note this is only for double inflation, if consider other potential, please change V.
# ai = 1 # initial value of scale factor


# # the system of differential equations to be solved
# def sys(var, T):
#     [x1,x2,y1,y2, z, a] = var

#     # Note that all derivatives are taken wrt the scaled, dimenstionless cosmic time T

#     dx1dT = y1
#     dx2dT=y2
#     dy1dT = -3*z*y1 - (mphi**2)*x1/m_p**2
#     dy2dT=-3*z*y2-(mchi**2)*x2/m_p**2
#     dzdT = -0.5*(y1**2+y2**2)*m_p**2
#     dadT = a*z
    
#     return [dx1dT,dx2dT,dy1dT,dy2dT,dzdT,dadT]

# T = np.linspace(0, 1000000000, 100000)


# # invoking the ODE solver
# sol = odeint(sys, [x1i,x2i,y1i,y2i,zi,ai], T, rtol=3e-14, atol=2e-35, mxstep=900000000)
# x1,x2, y1,y2, z, a = np.transpose(sol)
# phi,chi,phidot,chidot,H = x1*m_p,x2*m_p,y1*m_p**2,y2*m_p**2,z*m_p

# N = np.log(a/ai) # number of e-folds of expansion elapsed

# %% [markdown]
# ## References
#
# [1]Mukhanov, Viatcheslav. Physical foundations of cosmology. Cambridge university press, 2005.
#
# [2]Schmitz, Kai, and Gilles Vertongen. "Reheating and preheating after inflation: an introduction." reh 6 (2010): t2.
#
# [3] Bhatt, S.S., Mishra, S.S., Basak, S. and Sahoo, S.N., 2022. Numerical simulations of inflationary dynamics: slow-roll and beyond. arXiv preprint arXiv:2212.00529.
#
# [4]Baumann, Daniel. “TASI Lectures on Inflation.” arXiv: High Energy Physics - Theory (2009): n. pag.
#
# <!-- @book{Mukhanov:2005sc,
#     author = "Mukhanov, V.",
#     title = "{Physical Foundations of Cosmology}",
#     doi = "10.1017/CBO9780511790553",
#     isbn = "978-0-521-56398-7",
#     publisher = "Cambridge University Press",
#     address = "Oxford",
#     year = "2005"
# }
#
# @article{schmitz2010reheating,
#   title={Reheating and preheating after inflation: an introduction},
#   author={Schmitz, Kai and Vertongen, Gilles},
#   journal={reh},
#   volume={6},
#   pages={t2},
#   year={2010}
# }
# @article{bhatt2022numerical,
#   title={Numerical simulations of inflationary dynamics: slow-roll and beyond},
#   author={Bhatt, Siddharth S and Mishra, Swagat S and Basak, Soumen and Sahoo, Surya N},
#   journal={arXiv preprint arXiv:2212.00529},
#   year={2022},
#   publisher={Dec}
# }
# @inproceedings{Baumann:2009ds,
#     author = "Baumann, Daniel",
#     title = "{Inflation}",
#     booktitle = "{Theoretical Advanced Study Institute in Elementary Particle Physics}: {Physics of the Large and the Small}",
#     eprint = "0907.5424",
#     archivePrefix = "arXiv",
#     primaryClass = "hep-th",
#     reportNumber = "TASI-2009",
#     doi = "10.1142/9789814327183_0010",
#     pages = "523--686",
#     year = "2011"
# }-->
